# %% [markdown]
# <a href="https://colab.research.google.com/github/gitmonhub/Primeiro-site-HTML-basico/blob/main/C%C3%B3pia_de_3_Visualizando_Graficos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Matplotlib: Visualização com Python

# %% [markdown]
# Matplotlib é uma biblioteca abrangente para criar visualizações estáticas, animadas e interativas em Python. O Matplotlib torna as coisas fáceis fáceis e as difíceis possíveis.

# %% [markdown]
# Matplotlib é um dos pacotes Python mais populares usados ​​para visualização de dados. É uma biblioteca multiplataforma para fazer plotagens 2D a partir de dados em *arrays*. Para começar, basta fazer as importações necessárias, preparar alguns dados e começar a plotar com a ajuda da função **plot()** . Feito isso, lembre-se de mostrar seu gráfico usando a função **show()** .
#
# Matplotlib é escrito em Python e faz uso de **NumPy** , a extensão matemática numérica do Python.
#
# Falaremos desta biblioteca um pouco mais para frente...
#
# Fonte: https://matplotlib.org/

# %% [markdown]
# ## Gráfico de linha

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([0, 3, 6]) #relação das escalas medida do gráfico
y = np.array([0, 100, 250])

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Marcadores

# %% [markdown]
# Você pode usar o argumento de palavra-chave markerpara enfatizar cada ponto com um marcador especificado:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %% [markdown]
# Tipos de marcadores: https://matplotlib.org/stable/api/markers_api.html?highlight=marker#module-matplotlib.markers

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:g')
plt.show()

# %% [markdown]
# ## Várias linhas

# %% [markdown]
# Você pode plotar quantas linhas quiser simplesmente adicionando mais funções **plt.plot()**:

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %% [markdown]
# ## Criar rótulos para um gráfico

# %% [markdown]
# Com o Pyplot, você pode usar as funções xlabel()e ylabel()para definir um rótulo para os eixos x e y.

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# ## Criar um título

# %% [markdown]
# Com o Pyplot, você pode usar a title()função para definir um título para o gráfico.

# %% [markdown]
# ## Definir propriedades de fonte para título e rótulos

# %% [markdown]
# Você pode usar o fontdictparâmetro em xlabel(), ylabel()e title()para definir as propriedades da fonte para o título e os rótulos.

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

#exemplar do error abaixo
font1('family: serif', 'color: green', 'size: 80')
font2('family: serif')

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-335a1c575f05> in <module>()
#       2 y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
#       3
# ----> 4 font1('family: serif', 'color: green', 'size: 80')
#       5 font2('family: serif')
#       6
#
# TypeError: 'dict' object is not callable

# %% [markdown]
# # Criando gráficos de dispersão

# %% [markdown]
# Com o Pyplot, você pode usar a scatter()função para desenhar um gráfico de dispersão.
#
# A scatter()função traça um ponto para cada observação. Ele precisa de duas matrizes do mesmo comprimento, uma para os valores do eixo x e outra para os valores do eixo y:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %% [markdown]
# A observação no exemplo acima é o resultado de 13 carros passando.
#
# O eixo X mostra a idade do carro.
#
# O eixo Y mostra a velocidade do carro quando ele passa.

# %% [markdown]
# ## Exercício

# %% [markdown]
# Utilizando o exemplo acima dos carros e sua velocidade, complete a plotagem inserindo um título geral, um rótulo para o eixo x e um rótulo para o eixo y.

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.title("Análise de trânsito")
plt.xlabel("Idade dos carros")
plt.ylabel("Velocidade")

plt.scatter(x,y)
plt.show()

# %% [markdown]
# ## Mapa de cores

# %% [markdown]
# O módulo Matplotlib tem vários mapas de cores disponíveis.
#
# Um mapa de cores é como uma lista de cores, onde cada cor tem um valor que varia de 0 a 100.
#
# Aqui está um exemplo de um mapa de cores:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

#use a função title
#use a função xlabel
#use a função ylabel

plt.scatter(x, y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.title("Comidas")
plt.xlabel("Pessoas")
plt.ylabel("Quantia")

plt.scatter(x,y)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Este mapa de cores é chamado de **viridis** e, como você pode ver, varia de 0, que é uma cor roxa, e até 100, que é uma cor amarela.

# %% [markdown]
# ## Como usar o ColorMap

# %% [markdown]
# Você pode especificar o mapa de cores com o argumento de palavra-chave cmapcom o valor do mapa de cores, neste caso, 'viridis'que é um dos mapas de cores integrados disponíveis no Matplotlib.
#
# Além disso, você deve criar um array com valores (de 0 a 100), um valor para cada ponto no gráfico de dispersão:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %% [markdown]
# Você pode incluir o mapa de cores no desenho incluindo a plt.colorbar()declaração:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='plasma')

plt.colorbar()

plt.show()

# %% [markdown]
# # Gráfico de Barras

# %% [markdown]
# Com o Pyplot, você pode usar a bar()função para desenhar gráficos de barras:

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %% [markdown]
# Se você quiser que as barras sejam exibidas horizontalmente em vez de verticalmente, use a barh()função:

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %% [markdown]
# ## Cor da barra
# O bar()and barh()usa o argumento de palavra-chave colorpara definir a cor das barras:

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "red")
plt.show()

# %% [markdown]
# Ou você pode usar valores de cor hexadecimais :

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "#4CAF50")
plt.show()

# %% [markdown]
# # Histogramas Matplotlib

# %% [markdown]
# Um histograma é um gráfico que mostra as distribuições de frequência .
#
# É um gráfico que mostra o número de observações dentro de cada intervalo dado.
#
# Exemplo: digamos que você peça a altura de 250 pessoas, você pode acabar com um histograma como este:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Você pode ler no histograma que existem aproximadamente:
#
# 2 pessoas de 140 a 145cm
# 5 pessoas de 145 a 150cm
# 15 pessoas de 151 a 156cm
# 31 pessoas de 157 a 162cm
# 46 pessoas de 163 a 168cm
# 53 pessoas de 168 a 173cm
# 45 pessoas de 173 a 178cm
# 28 pessoas de 179 a 184cm
# 21 pessoas de 185 a 190cm
# 4 pessoas de 190 a 195cm

# %% [markdown]
# ### Criar histograma
# No Matplotlib, usamos a hist()função para criar histogramas.
#
# A hist()função usará uma matriz de números para criar um histograma, a matriz é enviada para a função como um argumento.
#
# Para simplificar, usamos o NumPy para gerar aleatoriamente uma matriz com 250 valores, onde os valores se concentrarão em torno de 170 e o desvio padrão é 10.

# %%
import numpy as np

x = np.random.normal(170, 10, 250)

print(x)

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# # Gráficos de pizza Matplotlib

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %% [markdown]
# Por padrão, a plotagem da primeira fatia começa no eixo x e se move no sentido anti-horário.

# %% [markdown]
# ## Rótulos
# Adicione rótulos ao gráfico de pizza com o labelparâmetro.
#
# O labelparâmetro deve ser uma matriz com um rótulo para cada fatia:

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# ## Explodir
# Talvez você queira que uma das cunhas se destaque? O explodeparâmetro permite que você faça isso.
#
# O explodeparâmetro, se especificado, e não None, deve ser uma matriz com um valor para cada fatia.
#
# Cada valor representa a que distância do centro cada cunha é exibida:

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# ## Legenda
# Para adicionar uma lista de explicação para cada cunha, use a legend()função:

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %% [markdown]
# # Plotagens 3D

# %%
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]
z = [1, 8, 27, 64, 125]
# Creating the figure object
fig = plt.figure()
# keeping the projection = 3d
# ctreates the 3d plot
ax = plt.axes(projection = '3d')
ax.plot3D(z, y, x)

# %% [markdown]
# # Exemplo prático

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
votos = np.array([842.201, 488.775, 553.424, 424.307, 272.500, 381.512, 261.386])
candi = ['Candidato A', 'Candidato B', 'Candidato C', 'Candidato D', 'Candidato E',
         'Candidato F', 'Candidato G']

cores=['gold', 'red', 'blue', 'magenta', 'green','lightskyblue', 'yellowgreen']
# o atributo explode indica que fatia do gráfico será destacada. No exemplo abaixo, será a primeira fatia. A quantidade de valores é igual ao número de fatias do gráfico. 
explode = (0.1, 0, 0, 0, 0, 0, 0)  # explode 1st slice

# Atribuindo um título ao gráfico
plt.title('Eleição 2020 - Total de Votos')

plt.pie(votos, explode=explode, labels=candi, colors=cores, autopct='%1.1f%%', shadow=True, startangle=90)

#Adiciona Legenda
plt.legend(candi, bbox_to_anchor=(1.3, 1.3),loc='upper right')

#Centraliza o gráfico
plt.axis('equal')

#Ajusta o espaçamento para evitar o recorte do rótulo
plt.tight_layout()

plt.show()

# %% [markdown]
# # Plotando Dados em Mapas com Python e Matplotlib Basemap Toolkit

# %% [markdown]
# O pacote de ferramentas matplotlib basemap é uma biblioteca para traçar dados 2D em mapas em Python.

# %%
# !pip install basemap

# %%
from mpl_toolkits import basemap
print(basemap.__version__)

# %%
# !apt-get install libgeos-3.6.2
# !apt-get install libgeos-dev

# %%
import numpy as np
import pandas as pd
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
dados = pd.read_csv('https://raw.githubusercontent.com/profandersonvanin01/python_introducao/main/housing.csv')

# %%
dados = dados[['latitude','longitude']]

# %%
dados.head()

# %%
plt.figure(figsize=(15,10))
plt.scatter(dados['longitude'].values,
            dados['latitude'].values,
            s=5, c='blue',
            alpha = 0.5, zorder=5)

# %%
def plot_map(lat1,lat2,lon1,lon2,xmap,ymap):
  plt.figure(figsize=(xmap,ymap))
  map = Basemap(projection='cyl', resolution='h',
                llcrnrlat=lat1, urcrnrlat=lat2,
                llcrnrlon=lon1, urcrnrlon=lon2)
  map.drawcoastlines()
  map.fillcontinents(color='palegoldenrod', lake_color='lightskyblue')
  map.drawmapboundary(fill_color='lightskyblue')
  map.drawparallels(np.arange(lat1, lat2 + 0.5, 2), labels=[1,0,0,0])
  map.drawmeridians(np.arange(lon1, lon2 + 0.5, 2), labels=[0,0,0,1])
  return map

# %% [markdown]
# https://medium.com/lejoaoconte/plotando-dados-em-mapas-com-python-e-matplotlib-basemap-toolkit-fc99add65722

# %%
multiplot=0.05
lat1 = dados['latitude'].min() - multiplot if dados['latitude'].min() < 0 else dados['latitude'].min() + multiplot
lat2 = dados['latitude'].max() - multiplot if dados['latitude'].max() < 0 else dados['latitude'].max() + multiplot
lon1 = dados['longitude'].min() - multiplot if dados['longitude'].min() < 0 else dados['longitude'].min() + multiplot
lon2 = dados['longitude'].max() - multiplot if dados['longitude'].max() < 0 else dados['longitude'].max() + multiplot

lat1, lat2 = round(lat1, 4), round(lat2, 4)
lon1, lon2 = round(lon1, 4), round(lon2, 4)

print(dados['latitude'].min(), dados['latitude'].max())
print(lat1, lat2)
print(dados['longitude'].min(), dados['longitude'].max())
print(lon1, lon2)

# %%
# !pip install basemap-data-hires

# %%
map = plot_map(lat1, lat2, lon1, lon2, 15, 10)

map.scatter(dados['longitude'].values,
            dados['latitude'].values,
            s = 5, c= 'blue',
            alpha = 0.5, zorder=5)
